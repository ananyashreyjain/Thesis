# %%
import pandas as pd
import numpy as  np
import tensorflow as tf

# %%
data=pd.read_csv("Design1a_Para2_S21.csv")

# %%
data.head()
# Out:
#    Freq [GHz]  \
# 0         1.0
# 1         1.1
# 2         1.2
# 3         1.3
# 4         1.4
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='1mm' s2='0.5mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='2mm' s2='0.5mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='3mm' s2='0.5mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='4mm' s2='0.5mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='5mm' s2='0.5mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='1mm' s2='1mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='2mm' s2='1mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='3mm' s2='1mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='0mm' g2='0mm' s1='4mm' s2='1mm'  \
# 0                                               -inf
# 1                                               -inf
# 2                                               -inf
# 3                                               -inf
# 4                                               -inf
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='1mm' s2='1.5mm'  \
# 0                                          -0.680799
# 1                                          -0.845104
# 2                                          -1.034539
# 3                                          -1.252251
# 4                                          -1.501954
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='2mm' s2='1.5mm'  \
# 0                                          -0.890213
# 1                                          -1.111187
# 2                                          -1.369147
# 3                                          -1.669585
# 4                                          -2.019084
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='3mm' s2='1.5mm'  \
# 0                                          -1.001806
# 1                                          -1.264132
# 2                                          -1.576040
# 3                                          -1.946740
# 4                                          -2.387668
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='4mm' s2='1.5mm'  \
# 0                                          -1.162021
# 1                                          -1.481307
# 2                                          -1.868085
# 3                                          -2.337269
# 4                                          -2.908003
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='5mm' s2='1.5mm'  \
# 0                                          -1.399727
# 1                                          -1.801839
# 2                                          -2.297861
# 3                                          -2.911946
# 4                                          -3.676443
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='1mm' s2='2mm'  \
# 0                                          -0.773223
# 1                                          -0.956926
# 2                                          -1.167445
# 3                                          -1.407813
# 4                                          -1.681577
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='2mm' s2='2mm'  \
# 0                                          -1.028858
# 1                                          -1.278987
# 2                                          -1.568240
# 3                                          -1.901746
# 4                                          -2.285596
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='3mm' s2='2mm'  \
# 0                                          -1.145530
# 1                                          -1.436946
# 2                                          -1.779575
# 3                                          -2.181853
# 4                                          -2.654119
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='4mm' s2='2mm'  \
# 0                                          -1.295512
# 1                                          -1.641933
# 2                                          -2.057079
# 3                                          -2.554778
# 4                                          -3.152574
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) [] - g1='10mm' g2='2mm' s1='5mm' s2='2mm'
# 0                                          -1.712422
# 1                                          -2.179723
# 2                                          -2.744214
# 3                                          -3.427390
# 4                                          -4.257601
#
# [5 rows x 601 columns]

# %%
remove_columns=[]
for index in range(0, data.shape[1]):
    if (data.iloc[:, index]==-1*np.inf).all():
        remove_columns.append(data.columns[index])
data=data.drop(remove_columns, axis=1)

# %%
def input_parameters():
    output=np.empty((0,4), float)
    for columns in data.columns[1:]:
        params=columns.split(' ')[3:]
        param=[]
        for vals in params:
            param.append(float(vals.split('=')[1][1:-3]))
        param=np.array([param])
        output=np.concatenate((output, param), axis=0)
    return output

# %%
data.shape
# Out:
# (191, 581)
